# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat
# %matplotlib inline

# %%
import xlsxwriter
from matplotlib.font_manager import FontProperties
from matplotlib.pyplot import figure, show
import seaborn as sns
from seaborn import countplot

# %%
xl = pd.read_excel("D:\Cancer_Data_set.xlsx")

# %%
xl.columns
# Out:
# Index(['Patient_Id', 'Age', 'Gender', 'Air_Pollution', 'Alcohol_use',
#        'Dust_Allergy', 'OccuPational_Hazards', 'Genetic_Risk', 'Balanced_Diet',
#        'Obesity', 'Smoking', 'Passive_Smoker', 'Abdomen_Pain',
#        'Coughing_of_Blood', 'Fatigue', 'Weight_Loss', 'Shortness_of_breath',
#        'Wheezing', 'Swallowing_Difficulty', 'Clubbing_of_Finger_Nails',
#        'Frequent_Cold', 'Dry_Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
xl.head()
# Out:
#   Patient_Id  Age  Gender  Air_Pollution  Alcohol_use  Dust_Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational_Hazards  Genetic_Risk  Balanced_Diet  Obesity   ...    \
# 0                     4             3              2        4   ...
# 1                     3             4              2        2   ...
# 2                     5             5              6        7   ...
# 3                     7             6              7        7   ...
# 4                     7             7              7        7   ...
#
#    Fatigue  Weight_Loss  Shortness_of_breath  Wheezing  Swallowing_Difficulty  \
# 0        3            4                    2         2                      3
# 1        1            3                    7         8                      6
# 2        8            7                    9         2                      1
# 3        4            2                    3         1                      4
# 4        3            2                    4         1                      4
#
#    Clubbing_of_Finger_Nails  Frequent_Cold  Dry_Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High
#
# [5 rows x 24 columns]

# %%
xl.shape
# Out:
# (1000, 24)

# %%
age =xl["Age"].value_counts().sort_index()
age.plot(kind='bar',x='Age Group', y='Age Index',figsize=(12,10),legend=True,linewidth=5.0)
plt.show()

# %%
Gender =xl["Gender"].value_counts().sort_index()
lege=('male','female')
plt.pie(Gender, labels = lege,startangle=90, shadow = True, radius = 1.2, autopct = '%1.1f%%') 
plt.legend() 
plt.show()

# %%
Air_Pollution =xl["Air_Pollution"].value_counts().sort_index()
Air_Pollution.plot(kind='bar',figsize=(15,12),legend=True,linewidth=5.0, fontsize=18)

# %%
Alcohol_use =xl["Alcohol_use"].value_counts().sort_index()
Alcohol_use.plot(kind='pie',autopct = '%1.1f%%',figsize=(10,10),fontsize=18)

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)

ax = countplot(xl['Dust_Allergy'])
total = len(xl['Dust_Allergy'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
who=('OccuPational_Hazards')
ax = countplot(xl['OccuPational_Hazards'])
total = len(xl['OccuPational_Hazards'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Genetic_Risk'])
total = len(xl['Genetic_Risk'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Balanced_Diet'])
total = len(xl['Balanced_Diet'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Obesity'])
total = len(xl['Obesity'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Smoking'])
total = len(xl['Smoking'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Passive_Smoker'])
total = len(xl['Passive_Smoker'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Abdomen_Pain'])
total = len(xl['Abdomen_Pain'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Coughing_of_Blood'])
total = len(xl['Coughing_of_Blood'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Fatigue'])
total = len(xl['Fatigue'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Weight_Loss'])
total = len(xl['Weight_Loss'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Shortness_of_breath'])
total = len(xl['Shortness_of_breath'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Wheezing'])
total = len(xl['Wheezing'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Swallowing_Difficulty'])
total = len(xl['Swallowing_Difficulty'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Clubbing_of_Finger_Nails'])
total = len(xl['Clubbing_of_Finger_Nails'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Frequent_Cold'])
total = len(xl['Frequent_Cold'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Dry_Cough'])
total = len(xl['Dry_Cough'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(12, 10))
sns.set(font_scale=1.2)
ax = countplot(xl['Snoring'])
total = len(xl['Snoring'])

for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.show()

# %%
figure(figsize=(8, 8))
Level =xl["Level"].value_counts().sort_index()
lege=('high','medium','low')
plt.pie(Level, labels = lege,startangle=90, radius = 1.2, autopct = '%1.1f%%') 
plt.legend() 
plt.show()
